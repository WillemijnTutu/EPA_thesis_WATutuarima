# %%
from ema_workbench import load_results
from ema_workbench.analysis import pairs_plotting
import matplotlib.pyplot as plt
from ema_workbench.analysis import feature_scoring
import seaborn as sns
from ema_workbench.analysis import prim
import pandas as pd
from SALib.analyze import sobol
from ema_workbench import Samplers
from ema_workbench.em_framework.salib_samplers import get_SALib_problem
from ema_workbench import Model, RealParameter, ScalarOutcome
from ema_workbench import MultiprocessingEvaluator, ema_logging

from ema_workbench import save_results
import numpy as np

# %% [markdown]
# # Read in data

# %%
BR_LHS_results2222 = load_results('../../results/results_BR_LHS_simplified/results_700_scenarios_BR_noOW_seed2222.gz')
BR_LHS_results3333 = load_results('../../results/results_BR_LHS_simplified/results_700_scenarios_BR_noOW_seed3333.gz')
BR_LHS_results4444 = load_results('../../results/results_BR_LHS_simplified/results_700_scenarios_BR_noOW_seed4444.gz')
BR_LHS_results5555 = load_results('../../results/results_BR_LHS_simplified/results_700_scenarios_BR_noOW_seed5555.gz')
BR_LHS_results6666 = load_results('../../results/results_BR_LHS_simplified/results_700_scenarios_BR_noOW_seed6666.gz')

# %%
BR_LHS_experiments2222, BR_LHS_outcomes2222 = BR_LHS_results2222
BR_LHS_experiments3333, BR_LHS_outcomes3333 = BR_LHS_results3333
BR_LHS_experiments4444, BR_LHS_outcomes4444 = BR_LHS_results4444
BR_LHS_experiments5555, BR_LHS_outcomes5555 = BR_LHS_results5555
BR_LHS_experiments6666, BR_LHS_outcomes6666 = BR_LHS_results6666

# %% [markdown]
# # Code for an analysis

# %%
def scenario_analysis(x, y):
    prim_alg = prim.Prim(x, y, threshold=0.6)
    box1 = prim_alg.find_box()
    box1.show_tradeoff()

# %% [markdown]
# # Seed 2222

# %%
stats_df = pd.DataFrame()
for key in list(BR_LHS_outcomes2222.keys()):
    df = pd.DataFrame(BR_LHS_outcomes2222[key])
    stats_df[key] = df.describe()

# %%
stats_df
# Out:
#        continuity_mean  continuity_vars  connectivity_mean  connectivity_vars  \
# count       700.000000       700.000000         700.000000         700.000000
# mean          2.274128         0.969725           3.665786           2.194355
# std           0.282077         0.253548           0.331150           0.347805
# min           1.197756         0.092531           2.485514           0.830697
# 25%           2.136927         0.846537           3.492886           2.071060
# 50%           2.345330         1.013661           3.747757           2.249729
# 75%           2.466649         1.134358           3.889806           2.399262
# max           2.820952         1.893545           4.367538           3.198324
#
#        node_frequency_mean  node_frequency_var
# count           700.000000          700.000000
# mean              5.298264            9.498901
# std               0.202834            0.458399
# min               4.577887            7.910871
# ...

# %% [markdown]
# ### Case: continuity mean

# %%
y = BR_LHS_outcomes2222['continuity_mean'] < 2.136927
scenario_analysis(BR_LHS_experiments2222, y)

# %%
y = BR_LHS_outcomes2222['continuity_mean'] > 2.466649	
scenario_analysis(BR_LHS_experiments2222, y)

# %%
y = BR_LHS_outcomes2222['continuity_mean'] > 2.345330	
scenario_analysis(BR_LHS_experiments2222, y)

# %% [markdown]
# ### Case: continuity var

# %%
y = BR_LHS_outcomes2222['continuity_vars'] > 1.134358	
scenario_analysis(BR_LHS_experiments2222, y)

# %%
y = BR_LHS_outcomes2222['continuity_vars'] < 0.846537
scenario_analysis(BR_LHS_experiments2222, y)

# %%
y = BR_LHS_outcomes2222['continuity_vars'] > 1.013661
scenario_analysis(BR_LHS_experiments2222, y)

# %% [markdown]
# ### Case: connectivity mean

# %%
y = BR_LHS_outcomes2222['connectivity_mean'] > 3.889806	
scenario_analysis(BR_LHS_experiments2222, y)

# %%
y = BR_LHS_outcomes2222['connectivity_mean'] < 3.492886	
scenario_analysis(BR_LHS_experiments2222, y)

# %%
y = BR_LHS_outcomes2222['connectivity_mean'] > 3.747757		
scenario_analysis(BR_LHS_experiments2222, y)

# %% [markdown]
# ### Case: connectivity var

# %%
y = BR_LHS_outcomes2222['connectivity_vars'] > 2.399262
scenario_analysis(BR_LHS_experiments2222, y)

# %%
y = BR_LHS_outcomes2222['connectivity_vars'] < 2.071060
scenario_analysis(BR_LHS_experiments2222, y)

# %%
y = BR_LHS_outcomes2222['connectivity_vars'] > 2.249729	
scenario_analysis(BR_LHS_experiments2222, y)

# %% [markdown]
# ### Case: node frequency mean

# %%
y = BR_LHS_outcomes2222['node_frequency_mean'] > 5.433179
scenario_analysis(BR_LHS_experiments2222, y)

# %%
y = BR_LHS_outcomes2222['node_frequency_mean'] < 5.184462
scenario_analysis(BR_LHS_experiments2222, y)

# %%
y = BR_LHS_outcomes2222['node_frequency_mean'] > 5.318795	
scenario_analysis(BR_LHS_experiments2222, y)

# %% [markdown]
# ### Case: node frequency var

# %%
y = BR_LHS_outcomes2222['node_frequency_var'] > 9.740805
scenario_analysis(BR_LHS_experiments2222, y)

# %%
y = BR_LHS_outcomes2222['node_frequency_var'] < 9.237457
scenario_analysis(BR_LHS_experiments2222, y)

# %%
y = BR_LHS_outcomes2222['node_frequency_var'] > 9.450370
scenario_analysis(BR_LHS_experiments2222, y)

# %% [markdown]
# # Seed 3333

# %%
stats_df = pd.DataFrame()
for key in list(BR_LHS_outcomes3333.keys()):
    df = pd.DataFrame(BR_LHS_outcomes3333[key])
    stats_df[key] = df.describe()

# %%
stats_df
# Out:
#        continuity_mean  continuity_vars  connectivity_mean  connectivity_vars  \
# count       700.000000       700.000000         700.000000         700.000000
# mean          2.447584         1.793061           3.868842           1.869366
# std           0.295983         0.570467           0.283888           0.263328
# min           1.284144         0.096388           2.679971           0.845792
# 25%           2.307527         1.565472           3.712559           1.732141
# 50%           2.500287         1.858283           3.918852           1.889410
# 75%           2.652481         2.115894           4.063451           2.033248
# max           3.095644         4.859350           4.390885           2.620355
#
#        node_frequency_mean  node_frequency_var
# count           700.000000          700.000000
# mean              5.580145            9.469426
# std               0.212128            0.599769
# min               4.827943            7.066805
# ...

# %% [markdown]
# ## Continuity mean

# %%
y = BR_LHS_outcomes3333['continuity_mean'] < 2.652481	
prim_alg = prim.Prim(BR_LHS_experiments3333, y, threshold=0.6)
box1 = prim_alg.find_box()
box1.show_tradeoff()

# %%
box_num = 6
box1.inspect(box_num)
box1.inspect(box_num, style="graph")
box1.show_pairs_scatter(box_num)
# Out:
# coverage    0.826667
# density     0.846004
# id                 6
# mass        0.732857
# mean        0.846004
# res_dim            2
# Name: 6, dtype: object
#
#        box 6
#          min       max                      qp values
# TA  1.002669  4.604313    [-1.0, 0.08908567486166008]
# RP  0.268912  0.999541  [5.370857940662708e-05, -1.0]

# %%
y = BR_LHS_outcomes3333['continuity_mean'] < 2.307527
scenario_analysis(BR_LHS_experiments3333, y)

# %% [markdown]
# ## Continuity vars

# %%
y = BR_LHS_outcomes3333['continuity_vars'] > 2.115894
scenario_analysis(BR_LHS_experiments3333, y)

# %%
y = BR_LHS_outcomes3333['continuity_vars'] < 1.565472
prim_alg = prim.Prim(BR_LHS_experiments3333, y, threshold=0.6)
box1 = prim_alg.find_box()
box1.show_tradeoff()

# %% [markdown]
# ### Node frequency mean

# %%
y = BR_LHS_outcomes3333['node_frequency_mean'] > 5.710269	
scenario_analysis(BR_LHS_experiments3333, y)

# %%
y = BR_LHS_outcomes3333['node_frequency_mean'] < 5.461073	
prim_alg = prim.Prim(BR_LHS_experiments3333, y, threshold=0.6)
box1 = prim_alg.find_box()
box1.show_tradeoff()

# %% [markdown]
# ## Node frequency var

# %%
y = BR_LHS_outcomes3333['node_frequency_var'] > 9.847560
scenario_analysis(BR_LHS_experiments3333, y)

# %%
y = BR_LHS_outcomes3333['node_frequency_var'] < 9.067598
scenario_analysis(BR_LHS_experiments3333, y)

# %% [markdown]
# # Seed 4444

# %%
stats_df = pd.DataFrame()
for key in list(BR_LHS_outcomes4444.keys()):
    df = pd.DataFrame(BR_LHS_outcomes4444[key])
    stats_df[key] = df.describe()

# %%
stats_df
# Out:
#        continuity_mean  continuity_vars  connectivity_mean  connectivity_vars  \
# count       700.000000       700.000000         700.000000         700.000000
# mean          2.894348         1.679135           3.762032           1.638246
# std           0.424891         0.512689           0.363236           0.279437
# min           1.433617         0.211281           2.394057           0.515794
# 25%           2.661370         1.389628           3.592169           1.508418
# 50%           2.954961         1.737893           3.798195           1.664110
# 75%           3.191575         1.980388           4.017161           1.820234
# max           3.735265         3.129307           4.682676           2.383723
#
#        node_frequency_mean  node_frequency_var
# count           700.000000          700.000000
# mean              5.734279            7.582763
# std               0.349616            0.839802
# min               4.803320            5.221197
# ...

# %% [markdown]
# ## Continuity mean

# %%
y = BR_LHS_outcomes4444['continuity_mean'] < 2.661370	
scenario_analysis(BR_LHS_experiments4444, y)

# %%
y = BR_LHS_outcomes4444['continuity_mean'] > 3.191575	
scenario_analysis(BR_LHS_experiments4444, y)

# %% [markdown]
# ### Continuity vars

# %%
y = BR_LHS_outcomes4444['continuity_vars'] > 1.980388		
scenario_analysis(BR_LHS_experiments4444, y)

# %%
y = BR_LHS_outcomes4444['continuity_vars'] < 1.389628			
scenario_analysis(BR_LHS_experiments4444, y)

# %% [markdown]
# ### Connectivity mean

# %%
y = BR_LHS_outcomes4444['connectivity_mean'] > 4.017161	
scenario_analysis(BR_LHS_experiments4444, y)

# %%
y = BR_LHS_outcomes4444['connectivity_mean'] < 3.592169	
scenario_analysis(BR_LHS_experiments4444, y)

# %% [markdown]
# ### Connectivity vars

# %%
y = BR_LHS_outcomes4444['connectivity_vars'] < 1.508418
scenario_analysis(BR_LHS_experiments4444, y)

# %%
y = BR_LHS_outcomes4444['connectivity_vars'] > 1.820234
scenario_analysis(BR_LHS_experiments4444, y)

# %% [markdown]
# ### Node frequency mean

# %%
y = BR_LHS_outcomes4444['node_frequency_mean'] < 5.489713	
scenario_analysis(BR_LHS_experiments4444, y)

# %%
y = BR_LHS_outcomes4444['node_frequency_mean'] > 5.990783
scenario_analysis(BR_LHS_experiments4444, y)

# %% [markdown]
# ### Node frequency vars

# %%
y = BR_LHS_outcomes4444['node_frequency_var'] < 7.003186
scenario_analysis(BR_LHS_experiments4444, y)

# %%
y = BR_LHS_outcomes4444['node_frequency_var'] > 8.235029
scenario_analysis(BR_LHS_experiments4444, y)

# %% [markdown]
# # Seed 5555

# %%
stats_df = pd.DataFrame()
for key in list(BR_LHS_outcomes5555.keys()):
    df = pd.DataFrame(BR_LHS_outcomes5555[key])
    stats_df[key] = df.describe()

# %%
stats_df
# Out:
#        continuity_mean  continuity_vars  connectivity_mean  connectivity_vars  \
# count       700.000000       700.000000         700.000000         700.000000
# mean          2.363680         1.448500           3.422161           2.011898
# std           0.379358         0.741115           0.359711           0.419084
# min           1.109683         0.098577           2.327142           0.678573
# 25%           2.101598         0.777382           3.176984           1.835212
# 50%           2.413263         1.402679           3.463949           2.077491
# 75%           2.653604         2.019345           3.701394           2.287137
# max           3.142000         3.427218           4.234201           2.825147
#
#        node_frequency_mean  node_frequency_var
# count           700.000000          700.000000
# mean              5.448993            8.541979
# std               0.303344            0.929006
# min               4.494565            6.848020
# ...

# %% [markdown]
# ### Continuity mean

# %%
y = BR_LHS_outcomes5555['continuity_mean'] < 2.101598
scenario_analysis(BR_LHS_experiments5555, y)

# %%
y = BR_LHS_outcomes5555['continuity_mean'] > 2.653604	
prim_alg = prim.Prim(BR_LHS_experiments5555, y, threshold=0.6)
box1 = prim_alg.find_box()
box1.show_tradeoff()

# %% [markdown]
# ### Continuity vars

# %%
y = BR_LHS_outcomes5555['continuity_vars'] < 0.777382
scenario_analysis(BR_LHS_experiments5555, y)

# %%
y = BR_LHS_outcomes5555['continuity_vars'] > 2.019345
scenario_analysis(BR_LHS_experiments5555, y)

# %% [markdown]
# ### Connectivity mean

# %%
y = BR_LHS_outcomes5555['connectivity_mean'] < 3.176984
scenario_analysis(BR_LHS_experiments5555, y)

# %%
	
y = BR_LHS_outcomes5555['connectivity_mean'] > 3.701394
scenario_analysis(BR_LHS_experiments5555, y)

# %% [markdown]
# ### Connectivity var

# %%
y = BR_LHS_outcomes5555['connectivity_vars'] < 1.835212
scenario_analysis(BR_LHS_experiments5555, y)

# %%
y = BR_LHS_outcomes5555['connectivity_vars'] > 2.287137	
scenario_analysis(BR_LHS_experiments5555, y)

# %% [markdown]
# ### Node frequency mean

# %%
y = BR_LHS_outcomes5555['node_frequency_mean'] < 5.242536	
scenario_analysis(BR_LHS_experiments5555, y)

# %%
y = BR_LHS_outcomes5555['node_frequency_mean'] > 5.686234
scenario_analysis(BR_LHS_experiments5555, y)

# %% [markdown]
# ### Node frequency var

# %%
y = BR_LHS_outcomes5555['node_frequency_var'] < 7.839961
scenario_analysis(BR_LHS_experiments5555, y)

# %%
y = BR_LHS_outcomes5555['node_frequency_var'] > 9.054071
scenario_analysis(BR_LHS_experiments5555, y)

# %% [markdown]
# # Seed 6666

# %%
stats_df = pd.DataFrame()
for key in list(BR_LHS_outcomes6666.keys()):
    df = pd.DataFrame(BR_LHS_outcomes6666[key])
    stats_df[key] = df.describe()

# %%
stats_df
# Out:
#        continuity_mean  continuity_vars  connectivity_mean  connectivity_vars  \
# count       700.000000       700.000000         700.000000         700.000000
# mean          2.853935         1.852502           3.603942           2.026423
# std           0.463168         0.712677           0.420309           0.387725
# min           1.233621         0.148342           2.251061           0.538056
# 25%           2.606980         1.400718           3.327962           1.831716
# 50%           2.937530         1.825940           3.644949           2.106724
# 75%           3.185013         2.286618           3.904046           2.283366
# max           3.609114         4.172504           4.456430           2.971932
#
#        node_frequency_mean  node_frequency_var
# count           700.000000          700.000000
# mean              5.554228            8.836444
# std               0.370538            0.633747
# min               4.136958            7.303660
# ...

# %% [markdown]
# ### Continuity mean

# %%
y = BR_LHS_outcomes5555['continuity_mean'] < 2.606980	
scenario_analysis(BR_LHS_experiments5555, y)

# %%
y = BR_LHS_outcomes5555['continuity_mean'] > 3.185013
scenario_analysis(BR_LHS_experiments5555, y)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[114], line 2
#       1 y = BR_LHS_outcomes5555['continuity_mean'] > 3.185013
# ----> 2 scenario_analysis(BR_LHS_experiments5555, y)
#
# Cell In[5], line 2, in scenario_analysis(x, y)
#       1 def scenario_analysis(x, y):
# ----> 2     prim_alg = prim.Prim(x, y, threshold=0.6)
#       3     box1 = prim_alg.find_box()
#       4     box1.show_tradeoff()
#
# File ~\miniconda3\envs\gds\lib\site-packages\ema_workbench\analysis\prim.py:968, in Prim.__init__(self, x, y, threshold, obj_function, peel_alpha, paste_alpha, mass_min, threshold_type, mode, update_function)
#     951 def __init__(
#     952     self,
#     953     x,
#    (...)
#     962     update_function="default",
#     963 ):
#     964     assert mode in {
#     965         sdutil.RuleInductionType.BINARY,
#     966         sdutil.RuleInductionType.REGRESSION,
# ...

# %% [markdown]
# ### Continuity vars

# %%
y = BR_LHS_outcomes5555['continuity_vars'] < 1.400718	
scenario_analysis(BR_LHS_experiments5555, y)

# %%
y = BR_LHS_outcomes5555['continuity_vars'] > 2.286618	
scenario_analysis(BR_LHS_experiments5555, y)

# %% [markdown]
# ### Connectivity mean

# %%
y = BR_LHS_outcomes5555['connectivity_mean'] < 3.327962
scenario_analysis(BR_LHS_experiments5555, y)

# %%
y = BR_LHS_outcomes5555['connectivity_mean'] > 3.904046	
scenario_analysis(BR_LHS_experiments5555, y)

# %% [markdown]
# ### Connectivity vars

# %%
y = BR_LHS_outcomes5555['connectivity_vars'] < 1.831716
scenario_analysis(BR_LHS_experiments5555, y)

# %%
y = BR_LHS_outcomes5555['connectivity_vars'] > 2.283366	
scenario_analysis(BR_LHS_experiments5555, y)

# %% [markdown]
# ### Node frequency mean

# %%
y = BR_LHS_outcomes5555['node_frequency_mean'] < 5.376742	
scenario_analysis(BR_LHS_experiments5555, y)

# %%
y = BR_LHS_outcomes5555['node_frequency_mean'] > 5.826814	
scenario_analysis(BR_LHS_experiments5555, y)

# %% [markdown]
# ### Node frequency vars

# %%
y = BR_LHS_outcomes5555['node_frequency_var'] < 8.405432	
scenario_analysis(BR_LHS_experiments5555, y)

# %%
y = BR_LHS_outcomes5555['node_frequency_var'] > 9.176564
scenario_analysis(BR_LHS_experiments5555, y)
